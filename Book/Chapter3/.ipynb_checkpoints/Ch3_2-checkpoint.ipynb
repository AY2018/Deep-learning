# %%
from keras.datasets import reuters
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
len (train_data)
# Out:
# 8982

# %%
# Transformation des données en vecteurs 
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros ((len(sequences), dimension)) 
    for i, sequence in enumerate(sequences):
        results [i, sequence] = 1. 
    return results

# Vectorisation des données d'apprentissage 
x_train = vectorize_sequences(train_data)
# Vectorisation des données de test 
x_test = vectorize_sequences(test_data)

# %%
# One hot encoding 
from tensorflow.keras.utils import to_categorical

one_hot_train_labels = to_categorical(train_labels) 
one_hot_test_labels = to_categorical(test_labels)

# %%
from keras import models 
from keras import layers
model = models.Sequential()
model.add(layers. Dense (64, activation='relu', input_shape=(10000,))) 
model.add(layers. Dense(64, activation='relu'))
model.add(layers. Dense (46, activation='softmax'))

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
x_val = x_train[:1000]
partial_x_train = x_train[1000:]

y_val = one_hot_train_labels[:1000] 
partial_y_train = one_hot_train_labels[1000:]

# %%
history = model. fit(partial_x_train, partial_y_train,
epochs=20,
batch_size=512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.3703 - loss: 3.2244 - val_accuracy: 0.6020 - val_loss: 1.8483
# Epoch 2/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6630 - loss: 1.6741 - val_accuracy: 0.7090 - val_loss: 1.4073
# Epoch 3/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7373 - loss: 1.2358 - val_accuracy: 0.7240 - val_loss: 1.2363
# Epoch 4/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7779 - loss: 1.0165 - val_accuracy: 0.7570 - val_loss: 1.1094
# Epoch 5/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8255 - loss: 0.8304 - val_accuracy: 0.7780 - val_loss: 1.0305
# Epoch 6/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8555 - loss: 0.7088 - val_accuracy: 0.7730 - val_loss: 0.9949
# Epoch 7/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8749 - loss: 0.5866 - val_accuracy: 0.7930 - val_loss: 0.9387
# Epoch 8/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8966 - loss: 0.5034 - val_accuracy: 0.8040 - val_loss: 0.9093
# Epoch 9/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9155 - loss: 0.4110 - val_accuracy: 0.8150 - val_loss: 0.8975
# Epoch 10/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9261 - loss: 0.3542 - val_accuracy: 0.7920 - val_loss: 0.9261
# Epoch 11/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9368 - loss: 0.2970 - val_accuracy: 0.8090 - val_loss: 0.8894
# Epoch 12/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9445 - loss: 0.2596 - val_accuracy: 0.8150 - val_loss: 0.8721
# Epoch 13/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9460 - loss: 0.2347 - val_accuracy: 0.8130 - val_loss: 0.8848
# Epoch 14/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9509 - loss: 0.2015 - val_accuracy: 0.8180 - val_loss: 0.8937
# Epoch 15/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9530 - loss: 0.1844 - val_accuracy: 0.8010 - val_loss: 0.9560
# Epoch 16/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9582 - loss: 0.1669 - val_accuracy: 0.8170 - val_loss: 0.8963
# Epoch 17/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9579 - loss: 0.1539 - val_accuracy: 0.8090 - val_loss: 0.8960
# Epoch 18/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9575 - loss: 0.1430 - val_accuracy: 0.8150 - val_loss: 0.9141
# Epoch 19/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9627 - loss: 0.1247 - val_accuracy: 0.8050 - val_loss: 0.9912
# Epoch 20/20
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9607 - loss: 0.1291 - val_accuracy: 0.8180 - val_loss: 0.9196

# %%
import matplotlib.pyplot as plt
loss = history.history['loss'] 
val_loss = history.history['val_loss'] 
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'bo', label='Entrainement') 
plt.plot(epochs, val_loss, 'b', label='Validation')
plt.title('Perte pendant l\'entraînement et la validation') 
plt.xlabel('Nombre d\'époques')
plt.ylabel('Perte')
plt.legend()
plt.show()

# %%
# Efface la figure plt.c1f()
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot (epochs, acc, 'bo', label='Entraînement')
plt.plot (epochs, val_acc, 'b', label='Validation') 
plt.title('Exactitude pendant I\'entraînement et la validation') 
plt.xlabel( 'Nombre d\'époques')
plt.ylabel ('Exactitude de prédiction') 
plt.legend ()
plt.show( )

# %%
model = models.Sequential()
model.add(layers. Dense (64, activation='relu', input_shape=(10000,))) 
model.add(layers. Dense(64, activation='relu'))
model.add(layers. Dense (46, activation='softmax'))


model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
metrics=[ 'accuracy'])

model. fit(partial_x_train, partial_y_train,
epochs=9,
batch_size=512, validation_data=(x_val, y_val))
# Out:
# Epoch 1/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.4002 - loss: 3.1743 - val_accuracy: 0.6300 - val_loss: 1.8223
# Epoch 2/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6579 - loss: 1.6584 - val_accuracy: 0.6960 - val_loss: 1.3901
# Epoch 3/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7351 - loss: 1.2279 - val_accuracy: 0.7320 - val_loss: 1.1961
# Epoch 4/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7799 - loss: 1.0144 - val_accuracy: 0.7710 - val_loss: 1.0886
# Epoch 5/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8174 - loss: 0.8475 - val_accuracy: 0.7650 - val_loss: 1.0364
# Epoch 6/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8457 - loss: 0.7003 - val_accuracy: 0.8010 - val_loss: 0.9587
# Epoch 7/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8832 - loss: 0.5635 - val_accuracy: 0.8110 - val_loss: 0.9132
# Epoch 8/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9091 - loss: 0.4623 - val_accuracy: 0.8160 - val_loss: 0.8908
# Epoch 9/9
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9149 - loss: 0.4061 - val_accuracy: 0.8130 - val_loss: 0.8805

# %%
results = model.evaluate(x_test, one_hot_test_labels)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 592us/step - accuracy: 0.7937 - loss: 0.9438

# %%
results
# Out:
# [0.9633468389511108, 0.7831701040267944]
